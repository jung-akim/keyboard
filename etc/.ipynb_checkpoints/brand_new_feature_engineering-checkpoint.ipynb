# %%
# Necessary imports
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.compat.python import lrange
import patsy
from scipy import stats

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from statsmodels.imputation import mice
from statsmodels.graphics.factorplots import interaction_plot
# %matplotlib inline

# %%
df = pd.read_pickle('clean_products_df.pkl')

# %%
# Assign features and target
df = pd.concat([df.iloc[:,3:-2], df.iloc[:,-1]], axis=1)
X = df[['price', 'rating', 'num_ratings', 'watcher', 'shipping', 'free_return', 'open_box', 'pre_owned', 'refurbished', 'benefits_charity']]
y = df.sold

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 1)

# %%
# Missing value Indicator variables:
# price, rating, shipping, 
# status(of the product: either open_box, pre_owned, refurbished, brand_new(baseline))

x_train.loc[:,'price_present'] = (~x_train['price'].isnull()).astype(int)
x_train.loc[:,'rating_present'] = (~x_train['rating'].isnull()).astype(int)
x_train.loc[:,'shipping_present'] = (~x_train['shipping'].isnull()).astype(int)
x_train.loc[:,'status_present'] = (~x_train['open_box'].isnull()).astype(int)
# Out:
# /Users/jungakim/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/jungakim/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
np.sum(pd.isna(x_train), axis=0)
# Out:
# price                  7
# rating              3418
# num_ratings            0
# watcher                0
# shipping               2
# free_return            0
# open_box               2
# pre_owned              2
# refurbished            2
# benefits_charity       0
# price_present          0
# rating_present         0
# shipping_present       0
# status_present         0
# dtype: int64

# %% [markdown]
# #### Imputation by Multiple imputation by chained equations

# %% [markdown]
# Note:<br>
# Re-define 'rating' variable since the missing ratings are obviously because of zero reviews for the products.<br>
# 'rating' is missing for all observations with zero number of ratings/reviews which makes sense, but at least 85% of the observations have zero reviews and 'rating' is a strong predictor for number of items sold.
# Before imputation, 'rating' was an average rating of all the ratings for the product. But, if we were to imputate the 85% of the ratings, we would have to define it differently, i.e., Estimated expected rating for the product.
# So, 15% of the ratings have a sample mean as their estimate of expected rating.
# 85%, the imputed ratings, would have the estimated expected rating by MICE algorithm which uses cycles of linear regression with all the other predictors regressing on 'rating'.

# %%
# Description of MICE algorithm: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3074241/
imp = mice.MICEData(x_train)
imp.set_imputer('rating', formula='price + num_ratings + watcher + shipping + free_return + shipping + free_return + open_box + pre_owned + refurbished + benefits_charity')
for j in range(np.sum(pd.isna(x_train.rating))//len(x_train)):
    imp.update_all()
x_train = imp.data.set_index(x_train.index)

# Assign columns to the variables for convenience
price, rating, num_ratings, watcher, shipping = \
x_train.price, x_train.rating, x_train.num_ratings, x_train.watcher, x_train.shipping 

free_return, open_box, pre_owned, refurbished, benefits_charity = \
x_train.free_return, x_train.open_box, x_train.pre_owned, x_train.refurbished, x_train.benefits_charity

price_present, rating_present, shipping_present, status_present = \
x_train.price_present, x_train.rating_present, x_train.shipping_present, x_train.status_present

sold = y_train

# %%
fig, ax = plt.subplots(3,4, figsize=(16,12)); fig.tight_layout(pad=2.4)
a = ax[0,0]
a.hist(price, edgecolor="k", bins = range(0, 185, 5))
a.set_xlim(0, price.quantile(.99))
a.set_xticks(range(0, 180, 25))
a.set_xticklabels(range(0, 180, 25))
range_y = range(0, price.count(), price.count()//20)
a.set_yticks(range_y)
a.set_yticklabels([round(y/price.count(),2) for y in range_y])
a.set_ylim(0, 800)
a.set_title('price')

a = ax[0,1]
a.hist(rating, align='left',edgecolor='k', bins = np.linspace(0.5, 5.5, 11))
a.set_xticks(np.linspace(1,5.5,10)[:-1])
a.set_xlim(.5,5.5)
range_y = range(0, rating.count(), rating.count()//5)
a.set_yticks(range_y)
a.set_yticklabels([round(y/rating.count(),2) for y in range_y])
# a.set_ylim(0,600)
a.set_title('rating')

a = ax[0,2]
a.hist(num_ratings, edgecolor='k', bins = np.linspace(0, 75, 16))
a.set_xticks(np.linspace(0, 75, 16))
# a.set_xlim(-1,35)
range_y = range(0, num_ratings.count(), num_ratings.count()//10)
a.set_yticks(range_y)
a.set_yticklabels([round(y/num_ratings.count(),2) for y in range_y])
# a.set_ylim(0, 200)
a.set_title('num_ratings')

a = ax[0,3]
a.hist(watcher, edgecolor='k',bins = np.linspace(0,35,36))
range_y = range(0, watcher.count(), watcher.count()//10)
a.set_xlim(0, 35)
a.set_xticks(np.linspace(0,35,8))
a.set_yticks(range_y)
a.set_yticklabels([round(y/watcher.count(),2) for y in range_y])
# a.set_ylim(0, 6000)
a.set_title('watcher');

a = ax[1,0]
a.hist(shipping, edgecolor = 'k', bins = np.linspace(0, 50, 11))
a.set_xticks(np.linspace(0, 50, 11))
a.set_xlim(0, 50)
range_y = range(0, shipping.count(), shipping.count()//10)
a.set_yticks(range_y)
a.set_yticklabels([round(y/shipping.count(),2) for y in range_y])
a.set_ylim(0, 4000)
a.set_title('shipping');

def draw_pie(axis, input, title, labels=['No', 'Yes']):
    a = ax[axis]
    a.pie(input, labels = labels, autopct = '%1.0f%%')
    a.set_title(title)
    
draw_pie((1,1), [sum(free_return == 0), sum(free_return == 1)], 'free_return')
draw_pie((1,2), [sum(open_box == 0), sum(open_box == 1)], 'open_box', None)
draw_pie((1,3), [sum(pre_owned == 0), sum(pre_owned == 1)], 'pre_owned', None)
draw_pie((2,0), [sum(refurbished == 0), sum(refurbished == 1)], 'refurbished', None)
draw_pie((2,1), [sum(benefits_charity == 0), sum(benefits_charity == 1)], 'benefits_charity', None)

a = ax[2,2]
a.hist(sold, edgecolor = 'k', bins = np.linspace(0, 1000, 1001))
a.set_xticks(np.linspace(0, 1000, 201))
a.set_xlim(0, 50)
range_y = range(0, sold.count(), sold.count()//10)
a.set_yticks(range_y)
a.set_yticklabels([round(y/sold.count(),2) for y in range_y])
a.set_title('sold')
a.set_ylim(0, 3000);

# %%
plt.figure(figsize=(12,9))
sns.heatmap(pd.concat([x_train, np.log(y_train+1)], axis = 1).corr(), cmap="seismic", annot=True, vmin=-1, vmax=1);

# %%
log_y = np.log(y_train + 1)
mreg = smf.ols(formula = 'log_y ~ x_train', data = x_train, missing = 'drop').fit()
display(mreg.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  log_y   R-squared:                       0.261
# Model:                            OLS   Adj. R-squared:                  0.258
# Method:                 Least Squares   F-statistic:                     92.57
# Date:                Mon, 13 Jul 2020   Prob (F-statistic):          1.46e-228
# Time:                        20:38:59   Log-Likelihood:                -6713.7
# No. Observations:                3693   AIC:                         1.346e+04
# Df Residuals:                    3678   BIC:                         1.355e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -0.5108      1.822     -0.280      0.779      -4.084       3.062
# x_train[0]     -0.0046      0.001     -7.916      0.000      -0.006      -0.003
# x_train[1]      0.0892      0.195      0.457      0.648      -0.294       0.472
# x_train[2]      0.0006      0.001      1.010      0.312      -0.001       0.002
# x_train[3]      0.0408      0.006      6.371      0.000       0.028       0.053
# x_train[4]     -0.0199      0.003     -5.891      0.000      -0.026      -0.013
# x_train[5]      0.8087      0.058     13.907      0.000       0.695       0.923
# x_train[6]     -0.4075      0.084     -4.842      0.000      -0.572      -0.243
# x_train[7]     -0.6917      0.064    -10.861      0.000      -0.817      -0.567
# x_train[8]      0.5171      0.138      3.735      0.000       0.246       0.789
# x_train[9]     -0.1324      0.353     -0.375      0.708      -0.825       0.560
# x_train[10]     1.1783      0.569      2.072      0.038       0.063       2.293
# x_train[11]     1.9692      0.114     17.325      0.000       1.746       2.192
# x_train[12]     0.6915      1.057      0.654      0.513      -1.380       2.763
# x_train[13]    -0.7517      1.057     -0.711      0.477      -2.823       1.320
# ==============================================================================
# Omnibus:                     1405.503   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5148.872
# Skew:                           1.907   Prob(JB):                         0.00
# Kurtosis:                       7.350   Cond. No.                     4.67e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### 1. sold vs price

# %%
fig, ax = plt.subplots(1,3, figsize = (12, 3))
ax[0].scatter(price, np.log(sold+1), marker = '.'); ax[0].set_xlim(0, 400); ax[0].set_ylim(0, 20); ax[0].set_title('origin')
ax[1].scatter(1/np.sqrt(price), np.log(sold+1), marker = '.');
ax[2].scatter(price**2, np.log(sold+1), marker = '.'); ax[2].set_ylim(0, 4000); ax[2].set_ylim(0, 25);

# %%
X, y = 1/np.sqrt(price), np.log(sold+1)
mreg = smf.ols(formula = 'y ~ X', data = pd.concat([X, y], axis = 1), missing = 'drop').fit()
display(mreg.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     50.46
# Date:                Mon, 13 Jul 2020   Prob (F-statistic):           1.45e-12
# Time:                        20:38:59   Log-Likelihood:                -7246.0
# No. Observations:                3693   AIC:                         1.450e+04
# Df Residuals:                    3691   BIC:                         1.451e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4483      0.076      5.882      0.000       0.299       0.598
# X              2.3654      0.333      7.103      0.000       1.713       3.018
# ==============================================================================
# Omnibus:                     1306.771   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3661.229
# Skew:                           1.910   Prob(JB):                         0.00
# Kurtosis:                       6.033   Cond. No.                         12.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### 2. sold vs rating

# %%
fig, ax = plt.subplots(1,3, figsize = (12,3))
ax[0].scatter(rating, np.log(sold+1), marker = '.'); ax[0].set_title('origin')
ax[1].scatter(np.exp(rating), np.log(sold+1), marker = '.')
ax[2].scatter(rating**4, np.log(sold+1), marker = '.')

# %%
X, y = np.exp(rating), np.log(sold+1)
mreg = smf.ols(formula = 'y ~ X', data = pd.concat([X, y], axis = 1), missing = 'drop').fit()
display(mreg.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     155.1
# Date:                Mon, 13 Jul 2020   Prob (F-statistic):           6.76e-35
# Time:                        20:39:00   Log-Likelihood:                -7195.1
# No. Observations:                3693   AIC:                         1.439e+04
# Df Residuals:                    3691   BIC:                         1.441e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.7700      0.220     -8.035      0.000      -2.202      -1.338
# X              0.0296      0.002     12.452      0.000       0.025       0.034
# ==============================================================================
# Omnibus:                     1484.135   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4979.134
# Skew:                           2.089   Prob(JB):                         0.00
# Kurtosis:                       6.859   Cond. No.                         731.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### 3. sold vs num_ratings

# %%
fig, ax = plt.subplots(1,3, figsize = (12, 3))
ax[0].scatter(num_ratings, np.log(sold+1), marker = '.')
ax[1].scatter(1/(num_ratings+1), np.log(sold+1), marker = '.'); ax[1].set_xlim(0, 0.4)
ax[2].scatter(num_ratings**2, np.log(sold+1), marker = '.');

# %%
X, y = 1/(num_ratings+1), np.log(sold+1)
mreg = smf.ols(formula = 'y ~ X', data = pd.concat([X, y], axis = 1), missing = 'drop').fit()
display(mreg.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.138
# Model:                            OLS   Adj. R-squared:                  0.137
# Method:                 Least Squares   F-statistic:                     588.5
# Date:                Mon, 13 Jul 2020   Prob (F-statistic):          9.66e-121
# Time:                        20:39:00   Log-Likelihood:                -6997.9
# No. Observations:                3693   AIC:                         1.400e+04
# Df Residuals:                    3691   BIC:                         1.401e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.6672      0.115     31.870      0.000       3.442       3.893
# X             -2.8830      0.119    -24.258      0.000      -3.116      -2.650
# ==============================================================================
# Omnibus:                     1574.163   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6020.973
# Skew:                           2.159   Prob(JB):                         0.00
# Kurtosis:                       7.526   Cond. No.                         8.57
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### 4. sold vs. watcher

# %%
sold.value_counts().sort_index()
# Out:
# 0        2446
# 1         225
# 2         106
# 3          73
# 4          58
#          ...
# 3852        2
# 3951        1
# 4109        2
# 6734        1
# 43701       1
# Name: sold, Length: 274, dtype: int64

# %%
fig, ax = plt.subplots(1,3, figsize = (12, 3))
ax[0].scatter(watcher, np.log(sold+1), marker = '.')
ax[1].scatter(1/(watcher**2+1), np.log(sold+1), marker = '.')
ax[2].scatter(num_ratings**2, np.log(sold+1), marker = '.')

# %%
X, y = watcher, np.log(sold+1)
mreg = smf.ols(formula = 'y ~ X', data = pd.concat([X, y], axis = 1), missing = 'drop').fit()
display(mreg.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     56.69
# Date:                Mon, 13 Jul 2020   Prob (F-statistic):           6.37e-14
# Time:                        20:39:01   Log-Likelihood:                -7243.0
# No. Observations:                3693   AIC:                         1.449e+04
# Df Residuals:                    3691   BIC:                         1.450e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9287      0.028     32.625      0.000       0.873       0.984
# X              0.0550      0.007      7.529      0.000       0.041       0.069
# ==============================================================================
# Omnibus:                     1436.314   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4559.831
# Skew:                           2.045   Prob(JB):                         0.00
# Kurtosis:                       6.593   Cond. No.                         3.92
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### 5. sold vs. shipping

# %%
fig, ax = plt.subplots(1,3, figsize = (12, 3))
ax[0].scatter(shipping, np.log(sold+1), marker = '.')
ax[1].scatter(1/(shipping+1)**4, np.log(sold+1), marker = '.')
ax[2].scatter(shipping**2, np.log(sold+1), marker = '.');

# %%
X, y = 1/(shipping+1), np.log(sold+1)
mreg = smf.ols(formula = 'y ~ X', data = pd.concat([X, y], axis = 1), missing = 'drop').fit()
display(mreg.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.068
# Method:                 Least Squares   F-statistic:                     272.4
# Date:                Mon, 13 Jul 2020   Prob (F-statistic):           4.30e-59
# Time:                        20:39:01   Log-Likelihood:                -7139.6
# No. Observations:                3693   AIC:                         1.428e+04
# Df Residuals:                    3691   BIC:                         1.430e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2299      0.052      4.453      0.000       0.129       0.331
# X              1.0506      0.064     16.504      0.000       0.926       1.175
# ==============================================================================
# Omnibus:                     1265.181   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3536.731
# Skew:                           1.839   Prob(JB):                         0.00
# Kurtosis:                       6.075   Cond. No.                         3.55
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### Transform the features into the x_train

# %%
plt.figure(figsize=(12,9))
sns.heatmap(pd.concat([x_train, np.log(y_train+1)], axis = 1).corr(), cmap="seismic", annot=True, vmin=-1, vmax=1);

# %%
log_y = np.log(y_train+1);
mreg = smf.ols(formula = 'log_y ~ x_train', data = x_train, missing = 'drop').fit()
display(mreg.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  log_y   R-squared:                       0.261
# Model:                            OLS   Adj. R-squared:                  0.258
# Method:                 Least Squares   F-statistic:                     92.57
# Date:                Mon, 13 Jul 2020   Prob (F-statistic):          1.46e-228
# Time:                        20:39:02   Log-Likelihood:                -6713.7
# No. Observations:                3693   AIC:                         1.346e+04
# Df Residuals:                    3678   BIC:                         1.355e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -0.5108      1.822     -0.280      0.779      -4.084       3.062
# x_train[0]     -0.0046      0.001     -7.916      0.000      -0.006      -0.003
# x_train[1]      0.0892      0.195      0.457      0.648      -0.294       0.472
# x_train[2]      0.0006      0.001      1.010      0.312      -0.001       0.002
# x_train[3]      0.0408      0.006      6.371      0.000       0.028       0.053
# x_train[4]     -0.0199      0.003     -5.891      0.000      -0.026      -0.013
# x_train[5]      0.8087      0.058     13.907      0.000       0.695       0.923
# x_train[6]     -0.4075      0.084     -4.842      0.000      -0.572      -0.243
# x_train[7]     -0.6917      0.064    -10.861      0.000      -0.817      -0.567
# x_train[8]      0.5171      0.138      3.735      0.000       0.246       0.789
# x_train[9]     -0.1324      0.353     -0.375      0.708      -0.825       0.560
# x_train[10]     1.1783      0.569      2.072      0.038       0.063       2.293
# x_train[11]     1.9692      0.114     17.325      0.000       1.746       2.192
# x_train[12]     0.6915      1.057      0.654      0.513      -1.380       2.763
# x_train[13]    -0.7517      1.057     -0.711      0.477      -2.823       1.320
# ==============================================================================
# Omnibus:                     1405.503   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5148.872
# Skew:                           1.907   Prob(JB):                         0.00
# Kurtosis:                       7.350   Cond. No.                     4.67e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
pre_x_train = x_train

x_train.loc[:,['price', 'rating', 'num_ratings', 'watcher', 'shipping']] = \
pd.concat([1/np.sqrt(price), np.exp(rating), 1/(num_ratings + 1), watcher, 1/(shipping + 1)], axis =1)

price, rating, num_ratings, watcher, shipping = \
x_train.price, x_train.rating, x_train.num_ratings, x_train.watcher, x_train.shipping

# %%
log_y = np.log(y_train+1);
mreg = smf.ols(formula = 'log_y ~ x_train', data = x_train, missing = 'drop').fit()
display(mreg.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  log_y   R-squared:                       0.319
# Model:                            OLS   Adj. R-squared:                  0.316
# Method:                 Least Squares   F-statistic:                     123.1
# Date:                Mon, 13 Jul 2020   Prob (F-statistic):          7.75e-294
# Time:                        20:39:02   Log-Likelihood:                -6561.6
# No. Observations:                3693   AIC:                         1.315e+04
# Df Residuals:                    3678   BIC:                         1.325e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.1203      1.562      0.077      0.939      -2.942       3.183
# x_train[0]      5.5666      0.296     18.837      0.000       4.987       6.146
# x_train[1]     -0.0006      0.003     -0.254      0.800      -0.006       0.004
# x_train[2]     -1.0804      0.269     -4.019      0.000      -1.607      -0.553
# x_train[3]      0.0411      0.006      6.698      0.000       0.029       0.053
# x_train[4]      0.7237      0.064     11.334      0.000       0.598       0.849
# x_train[5]      0.8039      0.056     14.349      0.000       0.694       0.914
# x_train[6]     -0.3508      0.081     -4.327      0.000      -0.510      -0.192
# x_train[7]     -0.7097      0.064    -11.152      0.000      -0.834      -0.585
# x_train[8]      0.5921      0.132      4.479      0.000       0.333       0.851
# x_train[9]      0.0232      0.339      0.068      0.945      -0.642       0.688
# x_train[10]     1.1546      0.546      2.115      0.034       0.085       2.225
# x_train[11]     1.2038      0.250      4.825      0.000       0.715       1.693
# x_train[12]     0.0142      1.015      0.014      0.989      -1.976       2.004
# x_train[13]    -1.0747      1.014     -1.060      0.289      -3.063       0.914
# ==============================================================================
# Omnibus:                     1188.261   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3717.016
# Skew:                           1.649   Prob(JB):                         0.00
# Kurtosis:                       6.644   Cond. No.                     7.22e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.22e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### Interaction effects

# %%
log_y = np.log(y_train+1); X = x_train
mreg = smf.ols(formula = 'log_y ~ X', data = X, missing = 'drop').fit()
def plot_interaction(var1, var2, xlim = None):
    log_y = np.log(y_train+1)
    fig, ax = plt.subplots(figsize=(50, 5))
    interaction_plot(x = var1, trace = var2, response = log_y, colors=['red','blue'], ax=ax)
    if xlim:
        plt.xlim(xlim)

    X = pd.concat([x_train, (var1 * var2)], axis =1)
    m = smf.ols(formula = 'log_y ~ X', data = X, missing = 'drop').fit()
    plt.show()
    df = pd.concat([pd.DataFrame(mreg.params), pd.DataFrame(m.params)], axis=1)
    print(df)
    print(f"\npre.rsquared: {mreg.rsquared}")
    print(f"pre.rsquared_adj: {mreg.rsquared_adj}\n")
    print(f"post.rsquared: {m.rsquared}")
    print(f"post.rsquared_adj: {m.rsquared_adj}")

# %% [markdown]
# price * free_return

# %%
plot_interaction(price, free_return)
# When the item is expensive, higher price has weaker effect on sale rate when it's free return.
# Out:
#                   0         0
# Intercept  0.120326  0.319632
# X[0]       5.566612  4.269975
# X[1]      -0.000648 -0.000305
# X[2]      -1.080411 -1.092813
# X[3]       0.041139  0.041793
# X[4]       0.723689  0.701201
# X[5]       0.803898 -0.309021
# X[6]      -0.350825 -0.338912
# X[7]      -0.709717 -0.690205
# X[8]       0.592065  0.625319
# X[9]       0.023215 -0.007187
# X[10]      1.154636  1.061000
# X[11]      1.203768  1.236366
# X[12]      0.014215  0.112379
# X[13]     -1.074734 -1.007384
# X[14]           NaN  5.559641
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.3316917400270858
# post.rsquared_adj: 0.3289654349143326

# %% [markdown]
# price * open_box

# %%
plot_interaction(price, open_box)
# When the item is expensive, price has little effect on sale rate when it's open-box status.
# Out:
#                   0         0
# Intercept  0.120326  0.092057
# X[0]       5.566612  5.979093
# X[1]      -0.000648 -0.000784
# X[2]      -1.080411 -1.059483
# X[3]       0.041139  0.041627
# X[4]       0.723689  0.710970
# X[5]       0.803898  0.801614
# X[6]      -0.350825  0.527246
# X[7]      -0.709717 -0.735080
# X[8]       0.592065  0.604589
# X[9]       0.023215  0.017701
# X[10]      1.154636  1.128589
# X[11]      1.203768  1.207264
# X[12]      0.014215 -0.000090
# X[13]     -1.074734 -1.086333
# X[14]           NaN -4.356729
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.3228353959641703
# post.rsquared_adj: 0.32007296217017045

# %% [markdown]
# price * pre_owned

# %%
plot_interaction(price, pre_owned)
# When the item is expensive, price has little effect on the sale rate when it's not pre-owned.
# Out:
#                   0         0
# Intercept  0.120326 -0.187612
# X[0]       5.566612  8.559466
# X[1]      -0.000648  0.000448
# X[2]      -1.080411 -1.091242
# X[3]       0.041139  0.043324
# X[4]       0.723689  0.696093
# X[5]       0.803898  0.808637
# X[6]      -0.350825 -0.357881
# X[7]      -0.709717  1.043045
# X[8]       0.592065  0.638034
# X[9]       0.023215 -0.050515
# X[10]      1.154636  1.063762
# X[11]      1.203768  1.195141
# X[12]      0.014215 -0.144749
# X[13]     -1.074734 -1.190966
# X[14]           NaN -7.648201
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.3505280491091858
# post.rsquared_adj: 0.34787858507237257

# %% [markdown]
# price * refurbished

# %%
plot_interaction(price, refurbished)
# Refurbished items have more effects on the sale rate compared to other status when the item is less expensive.
# When the item is expensive, refurbished items also have little effect on the sale rate.

# It seems that when used expensive items are on sale, sale rate is consistently low 
# regardless of whether the item is more expensive or not once the price has passed the threshold.
# Out:
#                   0         0
# Intercept  0.120326  0.126767
# X[0]       5.566612  5.756515
# X[1]      -0.000648 -0.001155
# X[2]      -1.080411 -1.049571
# X[3]       0.041139  0.039319
# X[4]       0.723689  0.725478
# X[5]       0.803898  0.802108
# X[6]      -0.350825 -0.349642
# X[7]      -0.709717 -0.718377
# X[8]       0.592065  1.934815
# X[9]       0.023215  0.024968
# X[10]      1.154636  1.141140
# X[11]      1.203768  1.223951
# X[12]      0.014215  0.004334
# X[13]     -1.074734 -1.080640
# X[14]           NaN -7.313074
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.3222020255065542
# post.rsquared_adj: 0.31943700793315155

# %% [markdown]
# price * benefits_charity

# %%
plot_interaction(price, benefits_charity)
# When the item profit is for charity, the sale rate is consistently low and
# it doesn't matter if it's highly expensive or not.
# Out:
#                   0         0
# Intercept  0.120326  0.119904
# X[0]       5.566612  5.570471
# X[1]      -0.000648 -0.000647
# X[2]      -1.080411 -1.080393
# X[3]       0.041139  0.041142
# X[4]       0.723689  0.723807
# X[5]       0.803898  0.804111
# X[6]      -0.350825 -0.351318
# X[7]      -0.709717 -0.709448
# X[8]       0.592065  0.592105
# X[9]       0.023215  0.902900
# X[10]      1.154636  1.154678
# X[11]      1.203768  1.203831
# X[12]      0.014215  0.013815
# X[13]     -1.074734 -1.075024
# X[14]           NaN -4.231502
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.3190645166265219
# post.rsquared_adj: 0.3162866998599725

# %% [markdown]
# rating * free_return

# %%
plot_interaction(rating, free_return)
# Out:
#                   0         0
# Intercept  0.120326  0.016868
# X[0]       5.566612  5.567190
# X[1]      -0.000648  0.000961
# X[2]      -1.080411 -1.114632
# X[3]       0.041139  0.041188
# X[4]       0.723689  0.723810
# X[5]       0.803898  1.037089
# X[6]      -0.350825 -0.349205
# X[7]      -0.709717 -0.710001
# X[8]       0.592065  0.595455
# X[9]       0.023215  0.024292
# X[10]      1.154636  1.149136
# X[11]      1.203768  1.169742
# X[12]      0.014215  0.012436
# X[13]     -1.074734 -1.076459
# X[14]           NaN -0.002523
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.319091481528331
# post.rsquared_adj: 0.3163137747627409

# %% [markdown]
# rating * open_box

# %%
plot_interaction(rating, open_box)
# When the item is not open-box, sale rate is less affected by higher rating.
# Out:
#                   0         0
# Intercept  0.120326  0.096382
# X[0]       5.566612  5.565979
# X[1]      -0.000648 -0.000419
# X[2]      -1.080411 -1.078855
# X[3]       0.041139  0.041100
# X[4]       0.723689  0.724447
# X[5]       0.803898  0.804442
# X[6]      -0.350825 -0.183030
# X[7]      -0.709717 -0.709203
# X[8]       0.592065  0.589869
# X[9]       0.023215  0.023434
# X[10]      1.154636  1.157126
# X[11]      1.203768  1.205908
# X[12]      0.014215  0.013205
# X[13]     -1.074734 -1.075485
# X[14]           NaN -0.001808
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.31904221123001286
# post.rsquared_adj: 0.3162643034705487

# %% [markdown]
# rating * pre_owned

# %%
plot_interaction(rating, pre_owned)
# Out:
#                   0         0
# Intercept  0.120326  0.061341
# X[0]       5.566612  5.570839
# X[1]      -0.000648  0.000187
# X[2]      -1.080411 -1.104145
# X[3]       0.041139  0.041367
# X[4]       0.723689  0.724526
# X[5]       0.803898  0.802215
# X[6]      -0.350825 -0.352055
# X[7]      -0.709717 -0.134121
# X[8]       0.592065  0.583390
# X[9]       0.023215  0.020831
# X[10]      1.154636  1.163163
# X[11]      1.203768  1.190944
# X[12]      0.014215  0.012132
# X[13]     -1.074734 -1.076444
# X[14]           NaN -0.006301
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.3192362131192803
# post.rsquared_adj: 0.31645909677356077

# %% [markdown]
# rating * refurbished

# %%
plot_interaction(rating, refurbished)

# Whether refurbished or not, the effect of rating on sale rate doesn't seem to change.
# Out:
#                   0         0
# Intercept  0.120326 -0.055821
# X[0]       5.566612  5.560697
# X[1]      -0.000648  0.001353
# X[2]      -1.080411 -1.097303
# X[3]       0.041139  0.041450
# X[4]       0.723689  0.724010
# X[5]       0.803898  0.804752
# X[6]      -0.350825 -0.353654
# X[7]      -0.709717 -0.708396
# X[8]       0.592065  2.116439
# X[9]       0.023215  0.026616
# X[10]      1.154636  1.172057
# X[11]      1.203768  1.195086
# X[12]      0.014215  0.010492
# X[13]     -1.074734 -1.078446
# X[14]           NaN -0.015423
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.3202602908074321
# post.rsquared_adj: 0.3174873520971008

# %% [markdown]
# rating * benefits_charity

# %%
plot_interaction(rating, benefits_charity)

# Too little data for benefits charity to make a judgement call.
# Out:
#                   0         0
# Intercept  0.120326  0.120326
# X[0]       5.566612  5.566612
# X[1]      -0.000648 -0.000648
# X[2]      -1.080411 -1.080411
# X[3]       0.041139  0.041139
# X[4]       0.723689  0.723689
# X[5]       0.803898  0.803898
# X[6]      -0.350825 -0.350825
# X[7]      -0.709717 -0.709717
# X[8]       0.592065  0.592065
# X[9]       0.023215  0.000003
# X[10]      1.154636  1.154636
# X[11]      1.203768  1.203768
# X[12]      0.014215  0.014215
# X[13]     -1.074734 -1.074734
# X[14]           NaN  0.000258
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.31902494377594226
# post.rsquared_adj: 0.31643286906492085

# %% [markdown]
# num_ratings * free_return

# %%
plot_interaction(num_ratings, free_return,(0,0.05))

# The number of ratings does not seem to have particular effect on sale rate when it's free return.
# Out:
#                   0         0
# Intercept  0.120326  0.289649
# X[0]       5.566612  5.563789
# X[1]      -0.000648 -0.000551
# X[2]      -1.080411 -1.216440
# X[3]       0.041139  0.041310
# X[4]       0.723689  0.723600
# X[5]       0.803898  0.603990
# X[6]      -0.350825 -0.344747
# X[7]      -0.709717 -0.708492
# X[8]       0.592065  0.610683
# X[9]       0.023215  0.025641
# X[10]      1.154636  1.117986
# X[11]      1.203768  1.189876
# X[12]      0.014215  0.009405
# X[13]     -1.074734 -1.079626
# X[14]           NaN  0.214666
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.3191953579025345
# post.rsquared_adj: 0.3164180748915305

# %% [markdown]
# num_ratings * open_box

# %%
plot_interaction(num_ratings, open_box,(0,0.1))

# The number of ratings doesn't seem to affect sale rate when it's open box
# Out:
#                   0         0
# Intercept  0.120326  0.075200
# X[0]       5.566612  5.569120
# X[1]      -0.000648 -0.000503
# X[2]      -1.080411 -1.018436
# X[3]       0.041139  0.041310
# X[4]       0.723689  0.717889
# X[5]       0.803898  0.799804
# X[6]      -0.350825  0.007788
# X[7]      -0.709717 -0.714120
# X[8]       0.592065  0.605962
# X[9]       0.023215  0.021625
# X[10]      1.154636  1.119591
# X[11]      1.203768  1.196009
# X[12]      0.014215  0.022140
# X[13]     -1.074734 -1.068836
# X[14]           NaN -0.395721
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.31937879589636053
# post.rsquared_adj: 0.3166022612046133

# %% [markdown]
# num_ratings * pre_owned

# %%
plot_interaction(num_ratings, pre_owned,(0,0.2))

# When there are more then 20 ratings, the number of ratings seem to have more dramatic effect on sale rate when it's pre_owned.
# Out:
#                   0         0
# Intercept  0.120326  0.131060
# X[0]       5.566612  5.564673
# X[1]      -0.000648 -0.000244
# X[2]      -1.080411 -1.148408
# X[3]       0.041139  0.041366
# X[4]       0.723689  0.726276
# X[5]       0.803898  0.802064
# X[6]      -0.350825 -0.353033
# X[7]      -0.709717 -1.154392
# X[8]       0.592065  0.578982
# X[9]       0.023215  0.019090
# X[10]      1.154636  1.178516
# X[11]      1.203768  1.186803
# X[12]      0.014215  0.010200
# X[13]     -1.074734 -1.077859
# X[14]           NaN  0.460269
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.31939902517336005
# post.rsquared_adj: 0.3166225730051796

# %% [markdown]
# num_ratings * refurbished

# %%
plot_interaction(num_ratings, refurbished,(0,0.1))
# Out:
#                   0         0
# Intercept  0.120326  0.243290
# X[0]       5.566612  5.569345
# X[1]      -0.000648  0.000030
# X[2]      -1.080411 -1.328227
# X[3]       0.041139  0.042722
# X[4]       0.723689  0.725096
# X[5]       0.803898  0.815551
# X[6]      -0.350825 -0.358387
# X[7]      -0.709717 -0.706002
# X[8]       0.592065 -0.366161
# X[9]       0.023215  0.031464
# X[10]      1.154636  1.228848
# X[11]      1.203768  1.104648
# X[12]      0.014215  0.002629
# X[13]     -1.074734 -1.085769
# X[14]           NaN  1.230170
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.32175004533152984
# post.rsquared_adj: 0.3189831839445223

# %% [markdown]
# num_ratings * benefits_charity

# %%
plot_interaction(num_ratings, benefits_charity,(0,0.1))
# Not too much data but seems like interaction exists.
# Out:
#                   0         0
# Intercept  0.120326  0.120326
# X[0]       5.566612  5.566612
# X[1]      -0.000648 -0.000648
# X[2]      -1.080411 -1.080411
# X[3]       0.041139  0.041139
# X[4]       0.723689  0.723689
# X[5]       0.803898  0.803898
# X[6]      -0.350825 -0.350825
# X[7]      -0.709717 -0.709717
# X[8]       0.592065  0.592065
# X[9]       0.023215  0.011608
# X[10]      1.154636  1.154636
# X[11]      1.203768  1.203768
# X[12]      0.014215  0.014215
# X[13]     -1.074734 -1.074734
# X[14]           NaN  0.011608
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.31902494377594226
# post.rsquared_adj: 0.31643286906492085

# %% [markdown]
# watcher * free_return

# %%
plot_interaction(watcher, free_return)
# Out:
#                   0         0
# Intercept  0.120326  0.128583
# X[0]       5.566612  5.553719
# X[1]      -0.000648 -0.000258
# X[2]      -1.080411 -1.148496
# X[3]       0.041139  0.054706
# X[4]       0.723689  0.726770
# X[5]       0.803898  0.826968
# X[6]      -0.350825 -0.348890
# X[7]      -0.709717 -0.701624
# X[8]       0.592065  0.651580
# X[9]       0.023215  0.026351
# X[10]      1.154636  1.189827
# X[11]      1.203768  1.173368
# X[12]      0.014215  0.004236
# X[13]     -1.074734 -1.083840
# X[14]           NaN -0.059466
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.32211989517363093
# post.rsquared_adj: 0.31935454255671625

# %% [markdown]
# watcher * open_box

# %%
plot_interaction(watcher, open_box)
# Out:
#                   0         0
# Intercept  0.120326  0.122803
# X[0]       5.566612  5.566253
# X[1]      -0.000648 -0.000676
# X[2]      -1.080411 -1.082161
# X[3]       0.041139  0.041426
# X[4]       0.723689  0.725077
# X[5]       0.803898  0.804453
# X[6]      -0.350825 -0.344224
# X[7]      -0.709717 -0.708890
# X[8]       0.592065  0.590750
# X[9]       0.023215  0.023317
# X[10]      1.154636  1.157123
# X[11]      1.203768  1.206426
# X[12]      0.014215  0.012868
# X[13]     -1.074734 -1.075591
# X[14]           NaN -0.043665
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.3190906532743579
# post.rsquared_adj: 0.31631294312997815

# %% [markdown]
# watcher * pre_owned

# %%
plot_interaction(watcher, pre_owned)
# Out:
#                   0         0
# Intercept  0.120326  0.123891
# X[0]       5.566612  5.564778
# X[1]      -0.000648 -0.000726
# X[2]      -1.080411 -1.077029
# X[3]       0.041139  0.039416
# X[4]       0.723689  0.721592
# X[5]       0.803898  0.803454
# X[6]      -0.350825 -0.351627
# X[7]      -0.709717 -0.715015
# X[8]       0.592065  0.595661
# X[9]       0.023215  0.024308
# X[10]      1.154636  1.153782
# X[11]      1.203768  1.206011
# X[12]      0.014215  0.016623
# X[13]     -1.074734 -1.073107
# X[14]           NaN  0.016043
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.31914818267068057
# post.rsquared_adj: 0.316370707212443

# %% [markdown]
# watcher * refurbished

# %%
plot_interaction(watcher, refurbished)
# Out:
#                   0         0
# Intercept  0.120326  0.157901
# X[0]       5.566612  5.551217
# X[1]      -0.000648 -0.000758
# X[2]      -1.080411 -1.113371
# X[3]       0.041139  0.050924
# X[4]       0.723689  0.724677
# X[5]       0.803898  0.808381
# X[6]      -0.350825 -0.349614
# X[7]      -0.709717 -0.706143
# X[8]       0.592065  0.719873
# X[9]       0.023215  0.027962
# X[10]      1.154636  1.168369
# X[11]      1.203768  1.203251
# X[12]      0.014215  0.007790
# X[13]     -1.074734 -1.081077
# X[14]           NaN -0.075221
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.32222385456591685
# post.rsquared_adj: 0.31945892604225323

# %% [markdown]
# watcher * benefits_charity

# %%
plot_interaction(watcher, benefits_charity)
# Out:
#                   0         0
# Intercept  0.120326  0.120326
# X[0]       5.566612  5.566612
# X[1]      -0.000648 -0.000648
# X[2]      -1.080411 -1.080411
# X[3]       0.041139  0.041139
# X[4]       0.723689  0.723689
# X[5]       0.803898  0.803898
# X[6]      -0.350825 -0.350825
# X[7]      -0.709717 -0.709717
# X[8]       0.592065  0.592065
# X[9]       0.023215  0.023215
# X[10]      1.154636  1.154636
# X[11]      1.203768  1.203768
# X[12]      0.014215  0.014215
# X[13]     -1.074734 -1.074734
# X[14]           NaN  0.000000
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.31902494377594226
# post.rsquared_adj: 0.31643286906492085

# %% [markdown]
# shipping * free_return

# %%
plot_interaction(shipping, free_return, (0, 0.4))
# Interaction seems to exist.
# Out:
#                   0         0
# Intercept  0.120326  0.060773
# X[0]       5.566612  5.536059
# X[1]      -0.000648 -0.000572
# X[2]      -1.080411 -1.089918
# X[3]       0.041139  0.040905
# X[4]       0.723689  0.624079
# X[5]       0.803898  0.409367
# X[6]      -0.350825 -0.367964
# X[7]      -0.709717 -0.725806
# X[8]       0.592065  0.562347
# X[9]       0.023215 -0.001521
# X[10]      1.154636  1.221517
# X[11]      1.203768  1.174292
# X[12]      0.014215  0.068621
# X[13]     -1.074734 -1.056435
# X[14]           NaN  0.500374
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.3212153176481862
# post.rsquared_adj: 0.3184462748863486

# %% [markdown]
# shipping * open_box

# %%
plot_interaction(shipping, open_box)
# Out:
#                   0         0
# Intercept  0.120326  0.122141
# X[0]       5.566612  5.568240
# X[1]      -0.000648 -0.000628
# X[2]      -1.080411 -1.077091
# X[3]       0.041139  0.041174
# X[4]       0.723689  0.700244
# X[5]       0.803898  0.801912
# X[6]      -0.350825 -0.453804
# X[7]      -0.709717 -0.720735
# X[8]       0.592065  0.594011
# X[9]       0.023215  0.025314
# X[10]      1.154636  1.144357
# X[11]      1.203768  1.197509
# X[12]      0.014215  0.030048
# X[13]     -1.074734 -1.067245
# X[14]           NaN  0.169704
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.3192013351841816
# post.rsquared_adj: 0.31642407655697535

# %% [markdown]
# shipping * pre_owned

# %%
plot_interaction(shipping, pre_owned)
# Interaction seems to exist
# Out:
#                   0         0
# Intercept  0.120326  0.119437
# X[0]       5.566612  5.516283
# X[1]      -0.000648 -0.000643
# X[2]      -1.080411 -1.082174
# X[3]       0.041139  0.041365
# X[4]       0.723689  0.796862
# X[5]       0.803898  0.808957
# X[6]      -0.350825 -0.332868
# X[7]      -0.709717 -0.575559
# X[8]       0.592065  0.592502
# X[9]       0.023215  0.046122
# X[10]      1.154636  1.169876
# X[11]      1.203768  1.195935
# X[12]      0.014215 -0.030366
# X[13]     -1.074734 -1.094070
# X[14]           NaN -0.267821
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.3197460498169038
# post.rsquared_adj: 0.31697101330541444

# %% [markdown]
# shipping * refurbished

# %%
plot_interaction(shipping, refurbished)
# Interaction seems to exist
# Out:
#                   0         0
# Intercept  0.120326  0.134935
# X[0]       5.566612  5.583066
# X[1]      -0.000648 -0.000514
# X[2]      -1.080411 -1.126526
# X[3]       0.041139  0.042050
# X[4]       0.723689  0.759421
# X[5]       0.803898  0.813451
# X[6]      -0.350825 -0.343811
# X[7]      -0.709717 -0.693262
# X[8]       0.592065  1.535571
# X[9]       0.023215  0.029423
# X[10]      1.154636  1.179951
# X[11]      1.203768  1.186159
# X[12]      0.014215 -0.013655
# X[13]     -1.074734 -1.089555
# X[14]           NaN -1.196239
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.32125596353027464
# post.rsquared_adj: 0.3184870865797591

# %% [markdown]
# shipping * benefits_charity

# %%
plot_interaction(shipping, benefits_charity)
# Out:
#                   0         0
# Intercept  0.120326  0.119340
# X[0]       5.566612  5.569974
# X[1]      -0.000648 -0.000646
# X[2]      -1.080411 -1.080170
# X[3]       0.041139  0.041135
# X[4]       0.723689  0.727126
# X[5]       0.803898  0.804160
# X[6]      -0.350825 -0.350619
# X[7]      -0.709717 -0.708406
# X[8]       0.592065  0.592191
# X[9]       0.023215  0.269485
# X[10]      1.154636  1.155124
# X[11]      1.203768  1.203353
# X[12]      0.014215  0.011898
# X[13]     -1.074734 -1.075765
# X[14]           NaN -0.500151
#
# pre.rsquared: 0.31902494377594226
# pre.rsquared_adj: 0.31643286906492085
#
# post.rsquared: 0.31910850216817077
# post.rsquared_adj: 0.3163308648367926

# %%
y = np.log(sold+1)
X = x_train
formula = \
'y ~ price * free_return + price * pre_owned' + \
' + shipping * pre_owned + shipping * refurbished' + \
' + price * watcher + price * shipping + num_ratings * shipping'

fit = smf.ols(formula = formula, data = pd.concat([X, y], axis=1), missing = 'drop').fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.399
# Model:                            OLS   Adj. R-squared:                  0.397
# Method:                 Least Squares   F-statistic:                     174.4
# Date:                Mon, 13 Jul 2020   Prob (F-statistic):               0.00
# Time:                        20:39:10   Log-Likelihood:                -6330.8
# No. Observations:                3693   AIC:                         1.269e+04
# Df Residuals:                    3678   BIC:                         1.278e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                1.9132      0.336      5.696      0.000       1.255       2.572
# price                    0.5397      0.603      0.895      0.371      -0.643       1.722
# free_return              0.4772      0.142      3.354      0.001       0.198       0.756
# price:free_return        1.8270      0.660      2.770      0.006       0.534       3.120
# pre_owned                0.4685      0.190      2.463      0.014       0.096       0.841
# price:pre_owned         -2.5501      0.682     -3.737      0.000      -3.888      -1.212
# shipping                -0.8864      0.364     -2.433      0.015      -1.601      -0.172
# shipping:pre_owned      -0.8357      0.133     -6.299      0.000      -1.096      -0.576
# refurbished              1.6807      0.285      5.905      0.000       1.123       2.239
# shipping:refurbished    -1.1908      0.326     -3.653      0.000      -1.830      -0.552
# watcher                  0.0121      0.013      0.938      0.348      -0.013       0.037
# price:watcher            0.2710      0.090      3.010      0.003       0.095       0.447
# price:shipping          11.4813      0.753     15.254      0.000      10.006      12.957
# num_ratings             -1.9217      0.308     -6.244      0.000      -2.525      -1.318
# num_ratings:shipping    -0.5694      0.330     -1.725      0.085      -1.216       0.078
# ==============================================================================
# Omnibus:                     1194.122   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3860.798
# Skew:                           1.642   Prob(JB):                         0.00
# Kurtosis:                       6.783   Cond. No.                         191.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
interaction_cols = \
pd.concat([(price * free_return).rename('price * free_return'),
          (price * pre_owned).rename('price * pre_owned'),
          (shipping * pre_owned).rename('shipping * pre_owned'),
          (shipping * refurbished).rename('shipping * refurbished'),
          (price * watcher).rename('price * watcher'),
          (price * shipping).rename('price * shipping'),
          (num_ratings * shipping).rename('num_ratings * shipping')], axis = 1)

x_train = pd.concat([x_train, interaction_cols], axis = 1)

# %%
plt.figure(figsize=(25,9))
sns.heatmap(pd.concat([x_train, np.log(y_train+1)], axis = 1).corr(), cmap="seismic", annot=True, vmin=-1, vmax=1, fmt='.2f');

# %%
pd.to_pickle(x_train, 'x_train.pkl')
pd.to_pickle(x_test, 'x_test.pkl')
pd.to_pickle(y_train, 'y_train.pkl')
pd.to_pickle(y_test, 'y_test.pkl')
